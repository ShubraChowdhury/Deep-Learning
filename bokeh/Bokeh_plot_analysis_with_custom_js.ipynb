# %%
import pandas as pd
#df_drsk = pd.read_csv('data/final_data/DRSK_FINAL_copy.csv', sep=',', header=0,  parse_dates=['date'],encoding = "ISO-8859-1" ,low_memory=True )
cols = ['BC_DT','ID_BB_GLOBAL','BANK_NAME','CERT','BB_3M_DEFAULT_PROB','BB_6M_DEFAULT_PROB','BB_5Y_DEFAULT_PROB','REGION','3M_DEF_mean_by_day_x','6M_DEF_mean_by_day_x','5Y_DEF_mean_by_day_x','REG_MEAN_3M','REG_MEAN_6M','REG_MEAN_5Y','REG_MEAN_3M_MA','REG_MEAN_6M_MA','REG_MEAN_5Y_MA','3M_Day_mean_MA','6M_Day_mean_MA','5Y_Day_mean_MA','30D_MA_3M_by_bank','30D_MA_6M_by_bank','30D_MA_5YR_by_bank','26ema_3M_by_bank','12ema_3M_by_bank','MACD_3M_by_bank','26ema_6M_by_bank','12ema_6M_by_bank','MACD_6M_by_bank','26ema_5YR_by_bank','12ema_5YR_by_bank','MACD_5YR_by_bank','26ema_1YR_by_bank','12ema_1YR_by_bank','MACD_1YR_by_bank','BB_RSK_ISSR_W_WATCH','RSK_BB_ISSR_W_WATCH_CHG_DATE','RSK_BB_ISSR_LIKELIHOOD_OF_DFLT','RSK_BB_IMPLIED_CDS_SPREAD','BB_RSK_ISSR_W_WATCH_NUM','RSK_BB_ISSR_DEFAULT_NUM','1Y_DEF_mean_by_day_x','REG_MEAN_1Y','REG_MEAN_1Y_MA','1Y_Day_mean_MA','30D_MA_1YR_by_bank']
dtypes = {'BC_DT':'object','ID_BB_GLOBAL':'object','BANK_NAME':'object','CERT':'object','BB_3M_DEFAULT_PROB':'float64','BB_6M_DEFAULT_PROB':'float64','BB_5Y_DEFAULT_PROB':'float64','REGION':'object','3M_DEF_mean_by_day_x':'float64','6M_DEF_mean_by_day_x':'float64','5Y_DEF_mean_by_day_x':'float64','REG_MEAN_3M':'float64','REG_MEAN_6M':'float64','REG_MEAN_5Y':'float64','REG_MEAN_3M_MA':'float64','REG_MEAN_6M_MA':'float64','REG_MEAN_5Y_MA':'float64','3M_Day_mean_MA':'float64','6M_Day_mean_MA':'float64','5Y_Day_mean_MA':'float64','30D_MA_3M_by_bank':'float64','30D_MA_6M_by_bank':'float64','30D_MA_5YR_by_bank':'float64','26ema_3M_by_bank':'float64','12ema_3M_by_bank':'float64','MACD_3M_by_bank':'float64','26ema_6M_by_bank':'float64','12ema_6M_by_bank':'float64','MACD_6M_by_bank':'float64','26ema_5YR_by_bank':'float64','12ema_5YR_by_bank':'float64','MACD_5YR_by_bank':'float64','26ema_1YR_by_bank':'float64','12ema_1YR_by_bank':'float64','MACD_1YR_by_bank':'float64','BB_RSK_ISSR_W_WATCH':'object','RSK_BB_ISSR_W_WATCH_CHG_DATE':'object','RSK_BB_ISSR_LIKELIHOOD_OF_DFLT':'float64','RSK_BB_IMPLIED_CDS_SPREAD':'float64','BB_RSK_ISSR_W_WATCH_NUM':'float64','RSK_BB_ISSR_DEFAULT_NUM':'float64','1Y_DEF_mean_by_day_x':'float64','REG_MEAN_1Y':'float64','REG_MEAN_1Y_MA':'float64','1Y_Day_mean_MA':'float64','30D_MA_1YR_by_bank':'float64'}
pdt =['BC_DT']

df_drsk = pd.read_csv('data/final_data/DRSK_FINAL_PREP_DATA.csv', sep=',', header=0,parse_dates=pdt,  dtype=dtypes,usecols=cols, encoding = "ISO-8859-1" ,low_memory=True )
len(df_drsk)

# %%
df_drsk=df_drsk.dropna()

# %%
df_drsk.rename(columns={'BC_DT':'date','ID_BB_GLOBAL':'ID','BANK_NAME':'Bank','CERT':'Cert','BB_RSK_ISSR_W_WATCH':'Risk_Watch','RSK_BB_ISSR_W_WATCH_CHG_DATE':'Risk_Change_date','RSK_BB_IMPLIED_CDS_SPREAD':'CDS_Spread','BB_RSK_ISSR_W_WATCH_NUM':'Risk_Watch_Num','RSK_BB_ISSR_DEFAULT_NUM':'Default_Num', 'BB_3M_DEFAULT_PROB':'3M_Default', 'BB_6M_DEFAULT_PROB':'6M_Default', 'RSK_BB_ISSR_LIKELIHOOD_OF_DFLT':'1Y_Default', 'BB_5Y_DEFAULT_PROB' :'5Y_Default', 'REGION':'Region', '3M_DEF_mean_by_day_x':'Day_3M', '6M_DEF_mean_by_day_x':'Day_6M', '5Y_DEF_mean_by_day_x':'Day_5Y', '1Y_DEF_mean_by_day_x':'Day_1Y', 'REG_MEAN_3M':'Reg_3M', 'REG_MEAN_6M':'Reg_6M', 'REG_MEAN_5Y':'Reg_5Y', 'REG_MEAN_1Y':'Reg_1Y', 'REG_MEAN_3M_MA':'Reg_MA_3M', 'REG_MEAN_6M_MA':'Reg_MA_6M', 'REG_MEAN_5Y_MA':'Reg_MA_5Y', 'REG_MEAN_1Y_MA':'Reg_MA_1Y', '3M_Day_mean_MA':'Day_MA_3M', '6M_Day_mean_MA':'Day_MA_6M', '5Y_Day_mean_MA':'Day_MA_5Y', '1Y_Day_mean_MA':'Day_MA_1Y',  '30D_MA_3M_by_bank':'Bank_MA_3M', '30D_MA_6M_by_bank':'Bank_MA_6M', '30D_MA_5YR_by_bank':'Bank_MA_5Y', '30D_MA_1YR_by_bank':'Bank_MA_1Y',   '26ema_3M_by_bank':'Bank_26EMA_3M', '12ema_3M_by_bank':'Bank_12EMA_3M', 'MACD_3M_by_bank':'Bank_MCD_3M', '26ema_6M_by_bank':'Bank_26EMA_6M', '12ema_6M_by_bank':'Bank_12EMA_6M', 'MACD_6M_by_bank':'Bank_MCD_6M', '26ema_5YR_by_bank':'Bank_26EMA_5Y', '12ema_5YR_by_bank':'Bank_12EMA_5Y', 'MACD_5YR_by_bank':'Bank_MCD_5Y', '26ema_1YR_by_bank':'Bank_26EMA_1Y', '12ema_1YR_by_bank':'Bank_12EMA_1Y', 'MACD_1YR_by_bank':'Bank_MCD_1Y'}, inplace=True)

# %%
'''
'date',
'ID',
'Bank',
'Cert',
'ID_And_Bank_Name'
'Region'

'BB_RSK_ISSR_W_WATCH',
'RSK_BB_ISSR_W_WATCH_CHG_DATE',
'RSK_BB_IMPLIED_CDS_SPREAD',
'BB_RSK_ISSR_W_WATCH_NUM',
'RSK_BB_ISSR_DEFAULT_NUM',
#### ORIGINAL Bloomberg Default###########
'3M_Default',
'6M_Default',
'5Y_Default',
'1Y_Default,
############ POLULATION MEAN BY DAY ##########
'Day_3M',
'Day_6M',
'Day_5Y',
'Day_1Y',
########### MEAN BY REGION BY DAY ############
 'Reg_3M',
 'Reg_6M',
 'Reg_5Y',
 'Reg_1Y',
########## 30 DAY MA BY REGION ###############  
 'Reg_MA_3M',
 'Reg_MA_6M',
 'Reg_MA_5Y',
 'Reg_MA_1Y',
#########  POPULATION 30 DAY MA BY DAY #################### 
 'Day_MA_3M',
 'Day_MA_6M',
 'Day_MA_5Y',
 'Day_MA_1Y',
##############  30 DAY MA BY BANK #######
 'Bank_MA_3M',
 'Bank_MA_6M',
 'Bank_MA_5Y',
 'Bank_MA_1Y',
######## 12 EMA  By BANK ################ 
 'Bank_12EMA_3M',
 'Bank_12EMA_6M',
 'Bank_12EMA_5Y',
 'Bank_12EMA_1Y',
######## 26 EMA  By BANK ################ 
 'Bank_26EMA_3M',
 'Bank_26EMA_6M',
 'Bank_26EMA_5Y',
 'Bank_26EMA_1Y',
######## MCD By BANK ################ 
 'Bank_MCD_3M',
 'Bank_MCD_6M',
 'Bank_MCD_5Y',
 'Bank_MCD_1Y',
 '''

# %%
df_drsk['ID_And_Bank_Name'] = df_drsk['ID']+'-'+df_drsk['Bank']
#df_drsk.columns.tolist()

# %%
 df_drsk[['ID','ID_And_Bank_Name','Region','date', '3M_Default','Day_3M']][df_drsk['ID']=='BBG000QJ0NM4'][:2]

# %%
from os.path import dirname, join
import pandas as pd
from bokeh.client import push_session
from bokeh.io import curdoc,push_notebook,show,output_notebook
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource,CustomJS #,Plot,DataRange1d
from bokeh.models.widgets import PreText, Select
from bokeh.plotting import figure,  output_file,gridplot
from ipywidgets import interact
from datetime import date
import random
import numpy as np
from bokeh.models.glyphs import Text
from bokeh.models import Legend
output_file("SMA_EMA_MACD_v2.html")
#output_notebook()

stats = PreText(text='', width=500)

df_BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFBTN6'].copy()
df_BBG000QHNWP0_OCEANFIRST_BANK = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QHNWP0'].copy()
df_BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFWBZ9'].copy()
df_BBG000QFB6H3_Doral_Bank_FSB = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFB6H3'].copy()
df_BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QHNCZ3'].copy()
df_BBG000FTHN91_SEACOAST_NATIONAL_BANK = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000FTHN91'].copy()
df_BBG000BF39K8_COMMERCE_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BF39K8'].copy()
df_BBG000QHSY53_PACIFIC_PREMIER_BANK = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QHSY53'].copy()
df_BBG000QF7Z02_BUSEY_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QF7Z02'].copy()
df_BBG000LNS0J4_First_NBC_Bank = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000LNS0J4'].copy()
df_BBG000FTTMD5_AmTrust_Bank = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000FTTMD5'].copy()
df_BBG000CFJF26_BankUnited_FSB = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000CFJF26'].copy()
df_BBG000FT84T1_METABANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000FT84T1'].copy()
df_BBG000QF52T6_ARVEST_BANK = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QF52T6'].copy()
df_BBG000G2V672_LUTHER_BURBANK_SAVINGS = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000G2V672'].copy()
df_BBG000BPK883_FLAGSTAR_BANK_FSB = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BPK883'].copy()
df_BBG000QFKB00_SANDY_SPRING_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFKB00'].copy()
df_BBG000BVK0F9_United_Commercial_Bank = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BVK0F9'].copy()
df_BBG000QHRDX9_Colonial_Bank = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QHRDX9'].copy()
df_BBG000QFFDD8_HANMI_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFFDD8'].copy()
df_BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BTK1G1'].copy()
df_BBG000QFG0K7_IRWIN_UNION_BANK_FSB = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFG0K7'].copy()
df_BBG000QFGC94_LAKELAND_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFGC94'].copy()
df_BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000FTHHX7'].copy()
df_BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QFBCC5'].copy()
df_BBG000BLWJ94_First_National_Bank = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BLWJ94'].copy()
df_BBG000G2NJS0_CHEMICAL_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000G2NJS0'].copy()
df_BBG000FTLDD3_WOODFOREST_NATIONAL_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000FTLDD3'].copy()
df_BBG000QHQ3V4_NEXBANK_SSB = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QHQ3V4'].copy()
df_BBG000QJBYZ4_Banc_of_California_National_Association = df_drsk[['ID','date','Reg_MA_5Y','1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000QJBYZ4'].copy()
df_BBG000M6TR37_SIGNATURE_BANK = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000M6TR37'].copy()
df_BBG000BXH871_BANK_OF_THE_OZARKS = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG000BXH871'].copy()
df_BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY = df_drsk[['ID','date','Reg_MA_5Y', '1Y_Default','Day_1Y','Reg_1Y','Reg_MA_1Y','Day_MA_1Y','Bank_MA_1Y','Bank_12EMA_1Y','Bank_26EMA_1Y','Bank_MCD_1Y','CDS_Spread','Risk_Watch_Num','Default_Num','Bank_12EMA_5Y','Bank_26EMA_5Y','Bank_MCD_5Y', 'Bank_MA_5Y', 'Day_MA_5Y','Reg_5Y', '5Y_Default','Day_5Y','ID_And_Bank_Name','Region']][df_drsk['ID']=='BBG001F4Q165'].copy()



BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY  =  ColumnDataSource(data=df_BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY)
BBG000QHNWP0_OCEANFIRST_BANK =  ColumnDataSource(data=df_BBG000QHNWP0_OCEANFIRST_BANK)
BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK =  ColumnDataSource(data=df_BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK)
BBG000QFB6H3_Doral_Bank_FSB =  ColumnDataSource(data=df_BBG000QFB6H3_Doral_Bank_FSB)
BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK  =  ColumnDataSource(data=df_BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK)
BBG000FTHN91_SEACOAST_NATIONAL_BANK =  ColumnDataSource(data=df_BBG000FTHN91_SEACOAST_NATIONAL_BANK)
BBG000BF39K8_COMMERCE_BANK =  ColumnDataSource(data=df_BBG000BF39K8_COMMERCE_BANK)
BBG000QHSY53_PACIFIC_PREMIER_BANK =  ColumnDataSource(data=df_BBG000QHSY53_PACIFIC_PREMIER_BANK)
BBG000QF7Z02_BUSEY_BANK =  ColumnDataSource(data=df_BBG000QF7Z02_BUSEY_BANK)
BBG000LNS0J4_First_NBC_Bank =  ColumnDataSource(data=df_BBG000LNS0J4_First_NBC_Bank)
BBG000FTTMD5_AmTrust_Bank =  ColumnDataSource(data=df_BBG000FTTMD5_AmTrust_Bank)
BBG000CFJF26_BankUnited_FSB =  ColumnDataSource(data=df_BBG000CFJF26_BankUnited_FSB)
BBG000FT84T1_METABANK =  ColumnDataSource(data=df_BBG000FT84T1_METABANK)
BBG000QF52T6_ARVEST_BANK =  ColumnDataSource(data=df_BBG000QF52T6_ARVEST_BANK)
BBG000G2V672_LUTHER_BURBANK_SAVINGS =  ColumnDataSource(data=df_BBG000G2V672_LUTHER_BURBANK_SAVINGS)
BBG000BPK883_FLAGSTAR_BANK_FSB =  ColumnDataSource(data=df_BBG000BPK883_FLAGSTAR_BANK_FSB)
BBG000QFKB00_SANDY_SPRING_BANK =  ColumnDataSource(data=df_BBG000QFKB00_SANDY_SPRING_BANK)
BBG000BVK0F9_United_Commercial_Bank =  ColumnDataSource(data=df_BBG000BVK0F9_United_Commercial_Bank)
BBG000QHRDX9_Colonial_Bank =  ColumnDataSource(data=df_BBG000QHRDX9_Colonial_Bank)
BBG000QFFDD8_HANMI_BANK =  ColumnDataSource(data=df_BBG000QFFDD8_HANMI_BANK)
BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY  =  ColumnDataSource(data=df_BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY)
BBG000QFG0K7_IRWIN_UNION_BANK_FSB =  ColumnDataSource(data=df_BBG000QFG0K7_IRWIN_UNION_BANK_FSB)
BBG000QFGC94_LAKELAND_BANK =  ColumnDataSource(data=df_BBG000QFGC94_LAKELAND_BANK)
BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION  =  ColumnDataSource(data=df_BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION)
BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST =  ColumnDataSource(data=df_BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST)
BBG000BLWJ94_First_National_Bank =  ColumnDataSource(data=df_BBG000BLWJ94_First_National_Bank)
BBG000G2NJS0_CHEMICAL_BANK =  ColumnDataSource(data=df_BBG000G2NJS0_CHEMICAL_BANK)
BBG000FTLDD3_WOODFOREST_NATIONAL_BANK =  ColumnDataSource(data=df_BBG000FTLDD3_WOODFOREST_NATIONAL_BANK)
BBG000QHQ3V4_NEXBANK_SSB =  ColumnDataSource(data=df_BBG000QHQ3V4_NEXBANK_SSB)
BBG000QJBYZ4_Banc_of_California_National_Association  =  ColumnDataSource(data=df_BBG000QJBYZ4_Banc_of_California_National_Association)
BBG000M6TR37_SIGNATURE_BANK =  ColumnDataSource(data=df_BBG000M6TR37_SIGNATURE_BANK)
BBG000BXH871_BANK_OF_THE_OZARKS =  ColumnDataSource(data=df_BBG000BXH871_BANK_OF_THE_OZARKS)
BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY  =  ColumnDataSource(data=df_BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY)
source = ColumnDataSource(data=df_BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY)




tools = 'pan,xbox_zoom,xbox_select,reset'
p = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='1Y Bank-Region-Universe')
p.line( x='date',y='1Y_Default', source = source,  line_width=1 , color='navy',selection_color="orange",legend='1Y Default')
p.line( x='date',y='Reg_1Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='1Y Region')
p.circle(x='date', y='Day_1Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='1Y Universe')



p1 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='5Y bank-Region-Universe')
p1.line( x='date',y='5Y_Default', source = source,  line_width=1 , color='navy',selection_color="orange",legend='5Y Default')
p1.line( x='date',y='Reg_5Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='5Y Region')
p1.circle(x='date', y='Day_5Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='5Y Universe')
p1.x_range = p.x_range


p2 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='1Y-MA Bank-Region-Universe')
p2.line( x='date',y='Bank_MA_1Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='1Y Bank')
p2.line( x='date',y='Reg_MA_1Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='1Y Region')
p2.circle(x='date', y='Day_MA_1Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='1Y Universe')
p2.x_range = p.x_range

p3 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='5Y-MA Bank-Region-Universe')
p3.line( x='date',y='Bank_MA_5Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='5Y Bank')
p3.line( x='date',y='Reg_MA_5Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='5Y Region')
p3.circle(x='date', y='Day_MA_5Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='5Y Universe')
p3.x_range = p.x_range


#=== EMA

p4 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='1Y-Bank  MA Vs EMA')
p4.line( x='date',y='Bank_MA_1Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='1Y--MA')
p4.line( x='date',y='Bank_12EMA_1Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='1Y-12EMA')
p4.line( x='date',y='Bank_26EMA_1Y', source = source,  line_width=1 , color='black',selection_color="orange", legend='1Y-26EMA')
p4.x_range = p.x_range

p5 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='5Y-Bank MA Vs EMA')
p5.line( x='date',y='Bank_MA_5Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='5Y MA')
p5.line( x='date',y='Bank_12EMA_5Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='5Y-12EMA')
p5.line( x='date',y='Bank_26EMA_5Y', source = source,  line_width=1 , color='black',selection_color="orange", legend='5Y-26EMA')
p5.x_range = p.x_range

#=== MACD

p6 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='1Y-Bank MA-EMA-MACD')
p6.line( x='date',y='Bank_MA_1Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='1Y Bank')
p6.line( x='date',y='Bank_MCD_1Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='1M MACD')
p6.circle(x='date', y='Bank_12EMA_1Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='1Y-12EMA')
p6.circle(x='date', y='Bank_26EMA_1Y', size=2, hover_color="red", source=source, color='blue',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='1Y-26EMA')
p6.x_range = p.x_range


p7 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='5Y-Bank MA-EMA-MACD')
p7.line( x='date',y='Bank_MA_5Y', source = source,  line_width=1 , color='navy',selection_color="orange",legend='5Y Bank')
p7.line( x='date',y='Bank_MCD_5Y', source = source,  line_width=1 , color='red',selection_color="orange", legend='5M MACD')
p7.circle(x='date', y='Bank_12EMA_5Y', size=2, hover_color="red", source=source, color='black',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='5Y-12EMA')
p7.circle(x='date', y='Bank_26EMA_5Y', size=2, hover_color="red", source=source, color='blue',selection_color="orange", alpha=0.6, nonselection_alpha=0.1, selection_alpha=0.4,legend='5Y-26EMA')
p7.x_range = p.x_range



p9 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='CDS Spread')
p9.line( x='date',y='CDS_Spread', source = source,  line_width=1 , color='navy',selection_color="orange",legend='CDS-Spread')
p9.x_range = p.x_range

p10 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='Risk Watch Number')
p10.line( x='date',y='Risk_Watch_Num', source = source,  line_width=1 , color='navy',selection_color="orange",legend='Risk Watch')
p10.x_range = p.x_range

p11 = figure(plot_width=700, plot_height=250, tools=tools, x_axis_type='datetime', active_drag="xbox_select",title='Default Number')
p11.line( x='date',y='Default_Num', source = source,  line_width=1 , color='navy',selection_color="orange",legend='Default Number')
p11.x_range = p.x_range



p0 = figure(plot_width=700, plot_height=60)
p0.text(0,0,text='Region',source = source)
p0.xgrid.visible = False
p0.ygrid.visible = False
p0.axis.visible = False 
p0.toolbar.logo = None
p0.toolbar_location = None
p0.background_fill_color = None
p0.border_fill_color = None
p0.min_border_left = 0
p0.min_border_right = 0
p0.min_border_top = 0
p0.min_border_bottom = 0



#select = Select(options =['BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY','BBG000QHNWP0_OCEANFIRST_BANK','BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK','BBG000QFB6H3_Doral_Bank,_FSB','BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK','BBG000FTHN91_SEACOAST_NATIONAL_BANK','BBG000BF39K8_COMMERCE_BANK','BBG000QHSY53_PACIFIC_PREMIER_BANK','BBG000QF7Z02_BUSEY_BANK','BBG000LNS0J4_First_NBC_Bank','BBG000FTTMD5_AmTrust_Bank','BBG000CFJF26_BankUnited,_FSB','BBG000FT84T1_METABANK','BBG000QF52T6_ARVEST_BANK','BBG000G2V672_LUTHER_BURBANK_SAVINGS','BBG000BPK883_FLAGSTAR_BANK,_FSB','BBG000QFKB00_SANDY_SPRING_BANK','BBG000BVK0F9_United_Commercial_Bank','BBG000QHRDX9_Colonial_Bank','BBG000QFFDD8_HANMI_BANK','BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY','BBG000QFG0K7_IRWIN_UNION_BANK,_FSB','BBG000QFGC94_LAKELAND_BANK','BBG000FTHHX7_RABOBANK,_NATIONAL_ASSOCIATION','BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST','BBG000BLWJ94_First_National_Bank','BBG000G2NJS0_CHEMICAL_BANK','BBG000FTLDD3_WOODFOREST_NATIONAL_BANK','BBG000QHQ3V4_NEXBANK_SSB','BBG000QJBYZ4_Banc_of_California,_National_Association','BBG000M6TR37_SIGNATURE_BANK','BBG000BXH871_BANK_OF_THE_OZARKS','BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY'], value='BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY') 
select = Select(options =['BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY','BBG000QHNWP0_OCEANFIRST_BANK','BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK','BBG000QFB6H3_Doral_Bank_FSB','BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK','BBG000FTHN91_SEACOAST_NATIONAL_BANK','BBG000BF39K8_COMMERCE_BANK','BBG000QHSY53_PACIFIC_PREMIER_BANK','BBG000QF7Z02_BUSEY_BANK','BBG000LNS0J4_First_NBC_Bank','BBG000FTTMD5_AmTrust_Bank','BBG000CFJF26_BankUnited_FSB','BBG000FT84T1_METABANK','BBG000QF52T6_ARVEST_BANK','BBG000G2V672_LUTHER_BURBANK_SAVINGS','BBG000BPK883_FLAGSTAR_BANK_FSB','BBG000QFKB00_SANDY_SPRING_BANK','BBG000BVK0F9_United_Commercial_Bank','BBG000QHRDX9_Colonial_Bank','BBG000QFFDD8_HANMI_BANK','BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY','BBG000QFG0K7_IRWIN_UNION_BANK_FSB','BBG000QFGC94_LAKELAND_BANK','BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION','BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST','BBG000BLWJ94_First_National_Bank','BBG000G2NJS0_CHEMICAL_BANK','BBG000FTLDD3_WOODFOREST_NATIONAL_BANK','BBG000QHQ3V4_NEXBANK_SSB','BBG000QJBYZ4_Banc_of_California_National_Association','BBG000M6TR37_SIGNATURE_BANK','BBG000BXH871_BANK_OF_THE_OZARKS','BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY'], value='BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY') 



codes_stk = """
var f = cb_obj.value;
var sdata = source.data;
var data1 = BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY.data;
var data2 = BBG000QHNWP0_OCEANFIRST_BANK.data;
var data3 = BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK.data;
var data4 = BBG000QFB6H3_Doral_Bank_FSB.data;
var data5 = BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK.data;
var data6 = BBG000FTHN91_SEACOAST_NATIONAL_BANK.data;
var data7 = BBG000BF39K8_COMMERCE_BANK.data;
var data8 = BBG000QHSY53_PACIFIC_PREMIER_BANK.data;
var data9 = BBG000QF7Z02_BUSEY_BANK.data;
var data10 = BBG000LNS0J4_First_NBC_Bank.data;
var data11 = BBG000FTTMD5_AmTrust_Bank.data;
var data12 = BBG000CFJF26_BankUnited_FSB.data;
var data13 = BBG000FT84T1_METABANK.data;
var data14 = BBG000QF52T6_ARVEST_BANK.data;
var data15 = BBG000G2V672_LUTHER_BURBANK_SAVINGS.data;
var data16 = BBG000BPK883_FLAGSTAR_BANK_FSB.data;
var data17 = BBG000QFKB00_SANDY_SPRING_BANK.data;
var data18 = BBG000BVK0F9_United_Commercial_Bank.data;
var data19 = BBG000QHRDX9_Colonial_Bank.data;
var data20 = BBG000QFFDD8_HANMI_BANK.data;
var data21 = BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY.data;
var data22 = BBG000QFG0K7_IRWIN_UNION_BANK_FSB.data;
var data23 = BBG000QFGC94_LAKELAND_BANK.data;
var data24 = BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION.data;
var data25 = BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST.data;
var data26 = BBG000BLWJ94_First_National_Bank.data;
var data27 = BBG000G2NJS0_CHEMICAL_BANK.data;
var data28 = BBG000FTLDD3_WOODFOREST_NATIONAL_BANK.data;
var data29 = BBG000QHQ3V4_NEXBANK_SSB.data;
var data30 = BBG000QJBYZ4_Banc_of_California_National_Association.data;
var data31 = BBG000M6TR37_SIGNATURE_BANK.data;
var data32 = BBG000BXH871_BANK_OF_THE_OZARKS.data;
var data33 = BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY.data;


console.log(data3);

for (key in data1) {console.log(key);}

if (f == "BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY") {
for (key in data1) {
    sdata[key] = [];
    for (i=0;i<data1[key].length;i++){
    sdata[key].push(data1[key][i]);
    }
}
} else if (f == "BBG000QHNWP0_OCEANFIRST_BANK") {
for (key in data2) {
    sdata[key] = [];
    for (i=0;i<data2[key].length;i++){
    sdata[key].push(data2[key][i]);
    }
}
}else if (f == "BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK") {
for (key in data3) {
    sdata[key] = [];
    for (i=0;i<data3[key].length;i++){
    sdata[key].push(data3[key][i]);
    }
}
}else if (f == "BBG000QFB6H3_Doral_Bank_FSB") {
for (key in data4) {
    sdata[key] = [];
    for (i=0;i<data4[key].length;i++){
    sdata[key].push(data4[key][i]);
    }
}
}else if (f == "BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK") {
for (key in data5) {
    sdata[key] = [];
    for (i=0;i<data5[key].length;i++){
    sdata[key].push(data5[key][i]);
    }
}
}else if (f == "BBG000FTHN91_SEACOAST_NATIONAL_BANK") {
for (key in data6) {
    sdata[key] = [];
    for (i=0;i<data6[key].length;i++){
    sdata[key].push(data6[key][i]);
    }
}
}else if (f == "BBG000BF39K8_COMMERCE_BANK") {
for (key in data7) {
    sdata[key] = [];
    for (i=0;i<data7[key].length;i++){
    sdata[key].push(data7[key][i]);
    }
}
}else if (f == "BBG000QHSY53_PACIFIC_PREMIER_BANK") {
for (key in data8) {
    sdata[key] = [];
    for (i=0;i<data8[key].length;i++){
    sdata[key].push(data8[key][i]);
    }
}
}else if (f == "BBG000QF7Z02_BUSEY_BANK") {
for (key in data9) {
    sdata[key] = [];
    for (i=0;i<data9[key].length;i++){
    sdata[key].push(data9[key][i]);
    }
}
}else if (f == "BBG000LNS0J4_First_NBC_Bank") {
for (key in data10) {
    sdata[key] = [];
    for (i=0;i<data10[key].length;i++){
    sdata[key].push(data10[key][i]);
    }
}
}else if (f == "BBG000FTTMD5_AmTrust_Bank") {
for (key in data11) {
    sdata[key] = [];
    for (i=0;i<data11[key].length;i++){
    sdata[key].push(data11[key][i]);
    }
}
}else if (f == "BBG000CFJF26_BankUnited_FSB") {
for (key in data12) {
    sdata[key] = [];
    for (i=0;i<data12[key].length;i++){
    sdata[key].push(data12[key][i]);
    }
}
}else if (f == "BBG000FT84T1_METABANK") {
for (key in data13) {
    sdata[key] = [];
    for (i=0;i<data13[key].length;i++){
    sdata[key].push(data13[key][i]);
    }
}
}else if (f == "BBG000QF52T6_ARVEST_BANK") {
for (key in data14) {
    sdata[key] = [];
    for (i=0;i<data14[key].length;i++){
    sdata[key].push(data14[key][i]);
    }
}
}else if (f == "BBG000G2V672_LUTHER_BURBANK_SAVINGS") {
for (key in data15) {
    sdata[key] = [];
    for (i=0;i<data15[key].length;i++){
    sdata[key].push(data15[key][i]);
    }
}
}else if (f == "BBG000BPK883_FLAGSTAR_BANK_FSB") {
for (key in data16) {
    sdata[key] = [];
    for (i=0;i<data16[key].length;i++){
    sdata[key].push(data16[key][i]);
    }
}
}else if (f == "BBG000QFKB00_SANDY_SPRING_BANK") {
for (key in data17) {
    sdata[key] = [];
    for (i=0;i<data17[key].length;i++){
    sdata[key].push(data17[key][i]);
    }
}
}else if (f == "BBG000BVK0F9_United_Commercial_Bank") {
for (key in data18) {
    sdata[key] = [];
    for (i=0;i<data18[key].length;i++){
    sdata[key].push(data18[key][i]);
    }
}
}else if (f == "BBG000QHRDX9_Colonial_Bank") {
for (key in data19) {
    sdata[key] = [];
    for (i=0;i<data19[key].length;i++){
    sdata[key].push(data19[key][i]);
    }
}
}else if (f == "BBG000QFFDD8_HANMI_BANK") {
for (key in data20) {
    sdata[key] = [];
    for (i=0;i<data20[key].length;i++){
    sdata[key].push(data20[key][i]);
    }
}
}else if (f == "BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY") {
for (key in data21) {
    sdata[key] = [];
    for (i=0;i<data21[key].length;i++){
    sdata[key].push(data21[key][i]);
    }
}
}else if (f == "BBG000QFG0K7_IRWIN_UNION_BANK_FSB") {
for (key in data22) {
    sdata[key] = [];
    for (i=0;i<data22[key].length;i++){
    sdata[key].push(data22[key][i]);
    }
}
}else if (f == "BBG000QFGC94_LAKELAND_BANK") {
for (key in data23) {
    sdata[key] = [];
    for (i=0;i<data23[key].length;i++){
    sdata[key].push(data23[key][i]);
    }
}
}else if (f == "BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION") {
for (key in data24) {
    sdata[key] = [];
    for (i=0;i<data24[key].length;i++){
    sdata[key].push(data24[key][i]);
    }
}
}else if (f == "BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST") {
for (key in data25) {
    sdata[key] = [];
    for (i=0;i<data25[key].length;i++){
    sdata[key].push(data25[key][i]);
    }
}
}else if (f == "BBG000BLWJ94_First_National_Bank") {
for (key in data26) {
    sdata[key] = [];
    for (i=0;i<data26[key].length;i++){
    sdata[key].push(data26[key][i]);
    }
}
}else if (f == "BBG000G2NJS0_CHEMICAL_BANK") {
for (key in data27) {
    sdata[key] = [];
    for (i=0;i<data27[key].length;i++){
    sdata[key].push(data27[key][i]);
    }
}
}else if (f == "BBG000FTLDD3_WOODFOREST_NATIONAL_BANK") {
for (key in data28) {
    sdata[key] = [];
    for (i=0;i<data28[key].length;i++){
    sdata[key].push(data28[key][i]);
    }
}
}else if (f == "BBG000QHQ3V4_NEXBANK_SSB") {
for (key in data29) {
    sdata[key] = [];
    for (i=0;i<data29[key].length;i++){
    sdata[key].push(data29[key][i]);
    }
}
}else if (f == "BBG000QJBYZ4_Banc_of_California_National_Association") {
for (key in data30) {
    sdata[key] = [];
    for (i=0;i<data30[key].length;i++){
    sdata[key].push(data30[key][i]);
    }
}
}else if (f == "BBG000M6TR37_SIGNATURE_BANK") {
for (key in data31) {
    sdata[key] = [];
    for (i=0;i<data31[key].length;i++){
    sdata[key].push(data31[key][i]);
    }
}
}else if (f == "BBG000BXH871_BANK_OF_THE_OZARKS") {
for (key in data32) {
    sdata[key] = [];
    for (i=0;i<data32[key].length;i++){
    sdata[key].push(data32[key][i]);
    }
}
}else {
for (key in data33) {
    sdata[key] = [];
    for (i=0;i<data33[key].length;i++){
    sdata[key].push(data33[key][i]);
    }
}
};
source.trigger("change");
"""



callback = CustomJS(args=dict(source=source, BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY=BBG000QFBTN6_FIRST_CITIZENS_BANK_AND_TRUST_COMPANY, BBG000QHNWP0_OCEANFIRST_BANK=BBG000QHNWP0_OCEANFIRST_BANK, BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK=BBG000QFWBZ9_EAST_BOSTON_SAVINGS_BANK, BBG000QFB6H3_Doral_Bank_FSB=BBG000QFB6H3_Doral_Bank_FSB, BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK=BBG000QHNCZ3_CAPITOL_FEDERAL_SAVINGS_BANK, BBG000FTHN91_SEACOAST_NATIONAL_BANK=BBG000FTHN91_SEACOAST_NATIONAL_BANK, BBG000BF39K8_COMMERCE_BANK=BBG000BF39K8_COMMERCE_BANK, BBG000QHSY53_PACIFIC_PREMIER_BANK=BBG000QHSY53_PACIFIC_PREMIER_BANK, BBG000QF7Z02_BUSEY_BANK=BBG000QF7Z02_BUSEY_BANK, BBG000LNS0J4_First_NBC_Bank=BBG000LNS0J4_First_NBC_Bank, BBG000FTTMD5_AmTrust_Bank=BBG000FTTMD5_AmTrust_Bank, BBG000CFJF26_BankUnited_FSB=BBG000CFJF26_BankUnited_FSB, BBG000FT84T1_METABANK=BBG000FT84T1_METABANK, BBG000QF52T6_ARVEST_BANK=BBG000QF52T6_ARVEST_BANK, BBG000G2V672_LUTHER_BURBANK_SAVINGS=BBG000G2V672_LUTHER_BURBANK_SAVINGS, BBG000BPK883_FLAGSTAR_BANK_FSB=BBG000BPK883_FLAGSTAR_BANK_FSB, BBG000QFKB00_SANDY_SPRING_BANK=BBG000QFKB00_SANDY_SPRING_BANK, BBG000BVK0F9_United_Commercial_Bank=BBG000BVK0F9_United_Commercial_Bank, BBG000QHRDX9_Colonial_Bank=BBG000QHRDX9_Colonial_Bank, BBG000QFFDD8_HANMI_BANK=BBG000QFFDD8_HANMI_BANK, BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY=BBG000BTK1G1_FIRST_UNITED_BANK_AND_TRUST_COMPANY, BBG000QFG0K7_IRWIN_UNION_BANK_FSB=BBG000QFG0K7_IRWIN_UNION_BANK_FSB, BBG000QFGC94_LAKELAND_BANK=BBG000QFGC94_LAKELAND_BANK, BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION=BBG000FTHHX7_RABOBANK_NATIONAL_ASSOCIATION, BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST=BBG000QFBCC5_ENTERPRISE_BANK_AND_TRUST, BBG000BLWJ94_First_National_Bank=BBG000BLWJ94_First_National_Bank, BBG000G2NJS0_CHEMICAL_BANK=BBG000G2NJS0_CHEMICAL_BANK, BBG000FTLDD3_WOODFOREST_NATIONAL_BANK=BBG000FTLDD3_WOODFOREST_NATIONAL_BANK, BBG000QHQ3V4_NEXBANK_SSB=BBG000QHQ3V4_NEXBANK_SSB, BBG000QJBYZ4_Banc_of_California_National_Association=BBG000QJBYZ4_Banc_of_California_National_Association, BBG000M6TR37_SIGNATURE_BANK=BBG000M6TR37_SIGNATURE_BANK, BBG000BXH871_BANK_OF_THE_OZARKS=BBG000BXH871_BANK_OF_THE_OZARKS, BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY=BBG001F4Q165_STATE_BANK_AND_TRUST_COMPANY), code=codes_stk)



select.callback = callback



widgets = row(p0, select)
main_row = row( widgets)
series = column(p,p2,p4,p6,p9,p10)
series1 = column(p1,p3,p5,p7,p11)
row3 = row(series,series1)
layout = column(main_row, row3)


show(layout)
print('done')

# %%
id_select =['BBG000QGCX18','BBG000FXYZF9']

# %%
xx = df_drsk[['ID_And_Bank_Name']][df_drsk['ID'].isin(id_select)]

# %%
list(xx.ID_And_Bank_Name.unique())

# %%
df_drsk[['date','Risk_Watch','Risk_Change_date','CDS_Spread','Risk_Watch_Num','Default_Num']][df_drsk['ID']=='BBG000QHRDX9']
